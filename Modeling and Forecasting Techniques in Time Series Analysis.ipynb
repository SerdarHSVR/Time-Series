# %% [markdown]
# Before submitting your HW, **please** rename it as yourname_yoursurname.ipynb.

# %%
import numpy as np
import scipy
from scipy import stats
import matplotlib.pyplot as plt

# %% [markdown]
# ----
# ## Below you will get your dataset, there is a parameter $p$, choose this parameter as  the ***square*** of the last digit of your student number (This is crucial for reproduction of your results).  Feel free to experiment with large and small smaples. Do your analysis for both large (size > 100) and small samples (size < 20).
# ----

# %%
def function(sample_size:int = 1000, p:int = 10) -> np.array:
    np.random.seed(p)
    A = 0.5 + np.random.randn(sample_size)
    B = np.random.chisquare(p, sample_size)
    return A + B


# My last digit of your student number is 2
p = 4


large_sample = function(150, p)  # Large sample > 100
small_sample = function(10, p)   # Small sample < 20

print("Large Sample Mean:", np.mean(large_sample))
print("Large Sample Std Dev:", np.std(large_sample))
print()

print("Small Sample Mean:", np.mean(small_sample))
print("Small Sample Std Dev:", np.std(small_sample))

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.hist(large_sample, bins=20, alpha=0.7, color='blue')
plt.title('Large Sample Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
plt.hist(small_sample, bins=10, alpha=0.7, color='orange')
plt.title('Small Sample Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()
# Out:
# Large Sample Mean: 4.613676067940746
# Large Sample Std Dev: 3.012351990478894
#
# Small Sample Mean: 4.113644166656073
# Small Sample Std Dev: 2.8691675301178

# %% [markdown]
# Now grab a cup of coffe and click [HERE](https://docs.scipy.org/doc/scipy/reference/stats.html). Then pick up the test that you like to test whether the data you will generate is sampled from a normal distribution. Explain the test that you use, the null hyp. and alternative hyp. Do a couple of tests to arrive at a clear conclusion.
